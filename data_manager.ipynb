# %%
from src.data import history_fetch, update_buffers

# %%
history_fetch("min", 4_000_000)
# Out:
# Start aquisition // history //- timescale: min - nb of data: 4000000
# Data from:  2017-05-22 19:46:09
# - Aquisition // history // (min) 0 / 4000000
# - Aquisition // history // (min) 1000 / 4000000
# - Aquisition // history // (min) 2000 / 4000000
# - Aquisition // history // (min) 3000 / 4000000
# - Aquisition // history // (min) 4000 / 4000000
# - Aquisition // history // (min) 5000 / 4000000
# - Aquisition // history // (min) 6000 / 4000000
# - Aquisition // history // (min) 7000 / 4000000
# - Aquisition // history // (min) 8000 / 4000000
# - Aquisition // history // (min) 9000 / 4000000
# - Aquisition // history // (min) 10000 / 4000000
# - Aquisition // history // (min) 11000 / 4000000
# - Aquisition // history // (min) 12000 / 4000000
# - Aquisition // history // (min) 13000 / 4000000
# - Aquisition // history // (min) 14000 / 4000000
# - Aquisition // history // (min) 15000 / 4000000
# - Aquisition // history // (min) 16000 / 4000000
# ...

# %%
history_fetch("sec", 50_000_000)
# Out:
# Start aquisition // history //- timescale: sec - nb of data: 50000000
# Data from:  2023-05-30 21:54:19
# - Aquisition // history // (sec) 0 / 50000000
# - Aquisition // history // (sec) 1000 / 50000000
# - Aquisition // history // (sec) 2000 / 50000000
# - Aquisition // history // (sec) 3000 / 50000000
# - Aquisition // history // (sec) 4000 / 50000000
# - Aquisition // history // (sec) 5000 / 50000000
# - Aquisition // history // (sec) 6000 / 50000000
# - Aquisition // history // (sec) 7000 / 50000000
# - Aquisition // history // (sec) 8000 / 50000000
# - Aquisition // history // (sec) 9000 / 50000000
# - Aquisition // history // (sec) 10000 / 50000000
# - Aquisition // history // (sec) 11000 / 50000000
# - Aquisition // history // (sec) 12000 / 50000000
# - Aquisition // history // (sec) 13000 / 50000000
# - Aquisition // history // (sec) 14000 / 50000000
# - Aquisition // history // (sec) 15000 / 50000000
# - Aquisition // history // (sec) 16000 / 50000000
# ...

# %%
update_buffers("history")
